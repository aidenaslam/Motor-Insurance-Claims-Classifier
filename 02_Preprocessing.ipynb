# %% [markdown]
# # Pre-Process Images

# %% [markdown]
# This notebook processes the images scraped from 01_Image_Scrape_Bing

# %%
# import libraries
import numpy as np

# Libraries to save names of images in Data folder
from os import listdir
from os.path import isfile, join

# keras load image, resize and save as array
import tensorflow as tf
from tensorflow.keras.preprocessing.image import load_img
#import image 
from tensorflow.keras.preprocessing.image import img_to_array

# %%
# Save names of images in Data folder into the variable images_in_folder
image_dir_0 = "C:/Users/Aiden/Documents/Data_Science_Stuff/sf_Data_Science_Stuff/Projects/05_Motor_Insurance_Claims_Classifier/dev_aiden/01_Image_Scrape/Data/Class_0/"
images_in_folder_0 = [image for image in listdir(image_dir_0) if isfile(join(image_dir_0, image))]

image_dir_1 = "C:/Users/Aiden/Documents/Data_Science_Stuff/sf_Data_Science_Stuff/Projects/05_Motor_Insurance_Claims_Classifier/dev_aiden/01_Image_Scrape/Data/Class_1/"
images_in_folder_1 = [image for image in listdir(image_dir_1) if isfile(join(image_dir_1, image))]

image_dir_2 = "C:/Users/Aiden/Documents/Data_Science_Stuff/sf_Data_Science_Stuff/Projects/05_Motor_Insurance_Claims_Classifier/dev_aiden/01_Image_Scrape/Data/Class_2/"
images_in_folder_2 = [image for image in listdir(image_dir_2) if isfile(join(image_dir_2, image))]

image_dir_3 = "C:/Users/Aiden/Documents/Data_Science_Stuff/sf_Data_Science_Stuff/Projects/05_Motor_Insurance_Claims_Classifier/dev_aiden/01_Image_Scrape/Data/Class_3/"
images_in_folder_3 = [image for image in listdir(image_dir_3) if isfile(join(image_dir_3, image))]

image_dir_4 = "C:/Users/Aiden/Documents/Data_Science_Stuff/sf_Data_Science_Stuff/Projects/05_Motor_Insurance_Claims_Classifier/dev_aiden/01_Image_Scrape/Data/Class_4/"
images_in_folder_4 = [image for image in listdir(image_dir_4) if isfile(join(image_dir_4, image))]

image_dir_5 = "C:/Users/Aiden/Documents/Data_Science_Stuff/sf_Data_Science_Stuff/Projects/05_Motor_Insurance_Claims_Classifier/dev_aiden/01_Image_Scrape/Data/Class_5/"
images_in_folder_5 = [image for image in listdir(image_dir_5) if isfile(join(image_dir_5, image))]

# %%
# Function to load each image and save as array
def import_image(directory, image):
    # load the image
    img = load_img(f'{directory}{image}')
      
    # convert to numpy array
    data = img_to_array(img)
    
    # convert image to size 224 x 224 (for ResNet)
    img_resized = tf.image.resize(data,[224,224])
    return img_resized

# %%
# Use load_image function to create dataset
##data_class_0 = np.array([np.array(import_image(image_dir_0, image)) for image in images_in_folder_0])
#data_class_1 = np.array([np.array(import_image(image_dir_1, image)) for image in images_in_folder_1])
##data_class_2 = np.array([np.array(import_image(image_dir_2, image)) for image in images_in_folder_2])
#data_class_3 = np.array([np.array(import_image(image_dir_3, image)) for image in images_in_folder_3])
#data_class_4 = np.array([np.array(import_image(image_dir_4, image)) for image in images_in_folder_4])
#data_class_5 = np.array([np.array(import_image(image_dir_5, image)) for image in images_in_folder_5])
# Out:
# ---------------------------------------------------------------------------
# UnidentifiedImageError                    Traceback (most recent call last)
# <ipython-input-19-b0def371d235> in <module>
#       4 ##data_class_2 = np.array([np.array(import_image(image_dir_2, image)) for image in images_in_folder_2])
#       5 #data_class_3 = np.array([np.array(import_image(image_dir_3, image)) for image in images_in_folder_3])
# ----> 6 data_class_4 = np.array([np.array(import_image(image_dir_4, image)) for image in images_in_folder_4])
#       7 #data_class_5 = np.array([np.array(import_image(image_dir_5, image)) for image in images_in_folder_5])
#
# <ipython-input-19-b0def371d235> in <listcomp>(.0)
#       4 ##data_class_2 = np.array([np.array(import_image(image_dir_2, image)) for image in images_in_folder_2])
#       5 #data_class_3 = np.array([np.array(import_image(image_dir_3, image)) for image in images_in_folder_3])
# ...

# %%
# 387 Images
data_class_0.shape
# Out:
# (387, 224, 224, 3)

# %%
# 357 Images
data_class_1.shape
# Out:
# (357, 224, 224, 3)

# %%
# 228 Images
data_class_2.shape
# Out:
# (228, 224, 224, 3)

# %%
# 206 Images
data_class_3.shape
# Out:
# (206, 224, 224, 3)

# %%
# 170 Images
data_class_4.shape
# Out:
# (170, 224, 224, 3)

# %%
# 221 Images
data_class_5.shape
# Out:
# (221, 224, 224, 3)

# %%
# Save images to pickle file
#data_class_0.dump('data_class_0.npy')
#data_class_1.dump('data_class_1.npy')
#data_class_2.dump('data_class_2.npy')
#data_class_3.dump('data_class_3.npy')
#data_class_4.dump('data_class_4.npy')
#data_class_5.dump('data_class_5.npy')

# Load image data from pickle file
data_class_0 = np.load('data_class_0.npy', allow_pickle=True)
data_class_1 = np.load('data_class_1.npy', allow_pickle=True)
data_class_2 = np.load('data_class_2.npy', allow_pickle=True)
data_class_3 = np.load('data_class_3.npy', allow_pickle=True)
data_class_4 = np.load('data_class_4.npy', allow_pickle=True)
data_class_5 = np.load('data_class_5.npy', allow_pickle=True)

# %% [markdown]
# ### Demonstration of image resizing

# %%
# Load random image from dataset
test_image_sample = 'FD0503596FBFF96DF215F6FA75FCE41AF1FFB898.png'
img = load_img(f'{image_dir}{test_image_sample}')
test_image_data = load_image(image_dir, test_image_sample)

# %%
test_image_data.shape
# Out:
# TensorShape([224, 224, 3])

# %%
from matplotlib import pyplot
pyplot.imshow(img)
pyplot.show()

# %%
# resize image
from tensorflow.keras.preprocessing.image import array_to_img
test_image_resized = tf.image.resize(test_image_data,[224,224])
img_resized = array_to_img(test_image_resized)
pyplot.imshow(img_resized)
pyplot.show()

# %%
test_image_resized.shape
# Out:
# TensorShape([224, 224, 3])

# %% [markdown]
# ## Data Augmentation

# %% [markdown]
# ### Demonstration using sample image

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from matplotlib.pyplot import imread, imshow, subplots, show


def plot(data_generator):
    """
    Plots 4 images generated by an object of the ImageDataGenerator class.
    """
    data_generator.fit(images)
    image_iterator = data_generator.flow(images)
    
    # Plot the images given by the iterator
    fig, rows = subplots(nrows=1, ncols=4, figsize=(18,18))
    for row in rows:
        row.imshow(image_iterator.next()[0].astype('int'))
        row.axis('off')
    show()
    
image = imread(f'{image_dir}{test_image_sample}',0)

# Creating a dataset which contains just one image.
images = image.reshape((1, image.shape[0], image.shape[1], image.shape[2]))

imshow(images[0])
show()

# %%
data_generator = ImageDataGenerator(rotation_range=90)
plot(data_generator)

# %%
y_class_0 = np.array
# Out:
# 387

# %% [markdown]
# ## Modelling
